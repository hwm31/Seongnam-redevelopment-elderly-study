# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install seaborn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 전체 데이터 조회

# %%
social17 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2017_총괄.csv", encoding='cp949')
social18 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2018_총괄.csv", encoding='cp949')
social19 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2019_총괄.csv", encoding='cp949')
social21 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2021_총괄.csv", encoding='cp949')
social22 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2022_총괄.csv", encoding='cp949')
social23 = pd.read_csv("/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/2023_총괄.csv", encoding='cp949')

# %%
datasets = {
    '2017': social17,
    '2018': social18,
    '2019': social19,
    '2021': social21,
    '2022': social22,
    '2023': social23
}

for year, df in datasets.items():
    null_rows = df[df.isnull().any(axis=1)]
    print(f"=== {year}년 데이터 ===")
    print(f"전체 데이터 수: {len(df)}")
    print(f"컬럼 수: {len(df.columns)}")
    print(f"총 null 값: {df.isnull().sum().sum()}")
    print(f"null이 있는 컬럼 수: {(df.isnull().sum() > 0).sum()}")
    print(f"null이 있는 행 수: {len(null_rows)}")

    if len(null_rows) > 0:
        print("null이 있는 컬럼들:")
        null_columns = df.columns[df.isnull().any()].tolist()
        print(null_columns)
    else:
        print("null이 있는 행 없음")

    print(f"=== {year}년 null 비율 ===")
    null_percent = (df.isnull().sum() / len(df) * 100).round(2)
    null_info = null_percent[null_percent > 0]  # null이 있는 컬럼만
    if len(null_info) > 0:
        print(null_info)
    else:
        print("null 값 없음")
    print("-" * 50)
# Out:
# === 2017년 데이터 ===
# 전체 데이터 수: 3330
# 컬럼 수: 158
# 총 null 값: 231765
# null이 있는 컬럼 수: 100
# null이 있는 행 수: 3330
# null이 있는 컬럼들:
# ...

# %% [markdown]
# # Column 명 통일

# %%
new_social17 = social17[['만나이','11.지역거주기간','11-1.향후거주의향','12.정주의식','14.거주지소속감','15.거주지만족도','13.주택만족도','24-1.월평균가구소득','29.부채유무','30.삶의만족도','19-1.대중교통만족여부_지하철', '19-2.대중교통만족여부_기차', '19-3.대중교통만족여부_택시', '19-4.대중교통만족여부_버스']].copy()
# 2017년 교통 관련 컬럼만 6→3, 1↔5 리버스
mapping_transport = {1:5, 2:4, 3:3, 4:2, 5:1, 6:3}
transport_cols_17 = ['19-1.대중교통만족여부_지하철', '19-2.대중교통만족여부_기차', '19-3.대중교통만족여부_택시', '19-4.대중교통만족여부_버스']
for col in transport_cols_17:
    new_social17[col] = new_social17[col].map(mapping_transport)
new_social17['19-1.대중교통만족여부_지하철'] = new_social17[transport_cols_17].mean(axis=1)
new_social17 = new_social17.drop(columns=['19-2.대중교통만족여부_기차', '19-3.대중교통만족여부_택시', '19-4.대중교통만족여부_버스'])
new_social17.columns = ['만나이','지역거주기간','향후거주의향','정주의식','거주지소속감','지역생활만족도','주거만족도','월평균가구소득','부채유무','삶의만족도','대중교통만족도']

# 2019년 데이터
new_social19 = social19[['만나이','11.지역거주기간','11-1.향후거주의향','12.정주의식','15.거주지소속감','16.거주지만족도','13.주택만족도','25-1.월평균가구소득','30.부채유무','33.삶의만족도','20-1.대중교통만족도_1지하철','20-2.대중교통만족도_2기차','20-3.대중교통만족도_3택시','20-4.대중교통만족도_4버스']].copy()
# 2019년 교통 관련 컬럼만 6→3, 1↔5 리버스
transport_cols_19 = ['20-1.대중교통만족도_1지하철','20-2.대중교통만족도_2기차','20-3.대중교통만족도_3택시','20-4.대중교통만족도_4버스']
for col in transport_cols_19:
    new_social19[col] = new_social19[col].map(mapping_transport)
new_social19['20-1.대중교통만족도_1지하철'] = new_social19[transport_cols_19].mean(axis=1)
new_social19 = new_social19.drop(columns=['20-2.대중교통만족도_2기차','20-3.대중교통만족도_3택시','20-4.대중교통만족도_4버스'])
new_social19.columns = ['만나이','지역거주기간','향후거주의향','정주의식','거주지소속감','지역생활만족도','주거만족도','월평균가구소득','부채유무','삶의만족도','대중교통만족도']

# 2023년 데이터
new_social23 = social23[['만나이','시군거주년수','시군향후거주의향정도코드1_1','정주의식코드_1','거주지소속감정도코드1_1','지역생활만족도코드','주택만족도코드1_1',
'월평균가구소득유형코드_1','부채여부_1','삶만족도코드','지하철만족도코드1_1','택시만족도코드1_1','기차만족도코드1_1','시내버스만족도코드1_1','시외버스만족도코드1_1']].copy()
# 2023년 교통 관련 컬럼만 6→3, 1↔5 리버스
transport_cols_23 = ['지하철만족도코드1_1', '택시만족도코드1_1', '기차만족도코드1_1', '시내버스만족도코드1_1', '시외버스만족도코드1_1']
for col in transport_cols_23:
    new_social23[col] = new_social23[col].map(mapping_transport)
new_social23['지하철만족도코드1_1'] = new_social23[transport_cols_23].mean(axis=1)
new_social23 = new_social23.drop(columns=['택시만족도코드1_1','기차만족도코드1_1','시내버스만족도코드1_1','시외버스만족도코드1_1'])
new_social23.columns = ['만나이','지역거주기간','향후거주의향','정주의식','거주지소속감','지역생활만족도','주거만족도','월평균가구소득','부채유무','삶의만족도','대중교통만족도']

new_social23['거주지소속감'] = new_social23['거주지소속감'].map({1: 4, 2: 3, 3: 2, 4: 1})
new_social23['월평균가구소득'] = new_social23['월평균가구소득'].map({1:1, 2:1, 3:2, 4:3, 5:4, 6:5, 7:6, 8:7, 9:8, 10:8})
new_social23['삶의만족도'] = new_social23['삶의만족도'].map({0:5, 1:5, 2:4, 3:4, 4:3, 5:3, 6:3, 7:2, 8:2, 9:1, 10:1})
new_social23['지역생활만족도'] = new_social23['지역생활만족도'].map({0:5, 1:5, 2:4, 3:4, 4:3, 5:3, 6:3, 7:2, 8:2, 9:1, 10:1})

# CSV 저장
new_social17.to_csv('/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/social17_preprocessed.csv', index=False, encoding='cp949')
new_social19.to_csv('/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/social19_preprocessed.csv', index=False, encoding='cp949')
new_social23.to_csv('/content/drive/MyDrive/2025-1학기 데이터과학 1조/Data/성남시 사회조사/social23_preprocessed.csv', index=False, encoding='cp949')

print('전처리 후 17년 : ')
print(new_social17)
print('='*50)
print('전처리 후 19년 : ')
print(new_social19)
print('='*50)
print('전처리 후 23년 : ')
print(new_social23)
print('='*50)
# Out:
# 전처리 후 17년 :
#       만나이  지역거주기간  향후거주의향  정주의식  거주지소속감  지역생활만족도  주거만족도  월평균가구소득  부채유무  삶의만족도  \
# 0      75     NaN     NaN     3       3        2      4      NaN   NaN      4
# 1      72     NaN     NaN     3       3        2      2      NaN   NaN      4
# 2      73     NaN     NaN     3       3        4      4      NaN   NaN      4
# 3      77     NaN     NaN     3       2        3      2      NaN   NaN      4
# 4      61     NaN     NaN     3       3        3      4      NaN   NaN      4
# ...   ...     ...     ...   ...     ...      ...    ...      ...   ...    ...
# 3325   41    14.0     2.0     3       3        1      2      6.0   1.0      2
# 3326   36     7.0     3.0     3       3        2      2      7.0   1.0      2
# 3327   34     1.0     2.0     3       2        3      2      3.0   2.0      2
# 3328   38     5.0     3.0     3       3        2      2      5.0   2.0      2
# 3329   39     2.0     3.0     4       1        3      4      5.0   2.0      3
#
#       대중교통만족도
# ...

# %%
print("social research 2017")
print(social17.head())

print("\nsocial research 2018")
print(social18.head())

print("\nsocial research 2019")
print(social19.head())

print("\nsocial research 2021")
print(social21.head())

print("\nsocial research 2022")
print(social22.head())

print("\nsocial research 2023")
print(social23.head())
# Out:
# social research 2017
#    가구 가중치  가구원 가중치   지역코드  가구원수_계(비교항목)  성별  1.주택형태  2.점유형태  5.가구주와의관계  \
# 0     NaN      189  31022             2   2     NaN     NaN          2
# 1     NaN      189  31022             2   2     NaN     NaN          2
# 2     NaN      189  31022             2   2     NaN     NaN          2
# 3     NaN      189  31022             2   2     NaN     NaN          2
# 4     NaN      189  31022             2   2     NaN     NaN          2
#
#    6.교육정도  6-1.수학여부  ...  47-1.행복마을만들기참여경로  47-2.행복마을참여생각  48.행복마을사업우선순위_0  \
# 0       1       NaN  ...               NaN            2.0                1
# 1       1       NaN  ...               NaN            2.0                1
# 2       1       NaN  ...               NaN            2.0                1
# 3       1       NaN  ...               NaN            2.0                7
# 4       2       1.0  ...               NaN            2.0                1
#
# ...

# %%
new_social17 = new_social17[new_social17['만나이'] >= 65].dropna()
new_social19 = new_social19[new_social19['만나이'] >= 65].dropna()
new_social23 = new_social23[new_social23['만나이'] >= 65].dropna()

print("\nsocial research 2017")
print(new_social17.head())
print("\n17 data count:")
print(len(new_social17))

print("\nsocial research 2019")
print(new_social19.head())
print("\n19 data count:")
print(len(new_social19))

print("\nsocial research 2023")
print(new_social23.head())
print("\n23 data count:")
print(len(new_social23))
# Out:
# social research 2017
#       만나이  지역거주기간  향후거주의향  정주의식  거주지소속감  지역생활만족도  주거만족도  월평균가구소득  부채유무  삶의만족도  \
# 1730   78    78.0     1.0     1       3        3      2      1.0   2.0      3
# 1731   65     6.0     2.0     3       2        2      3      2.0   1.0      2
# 1732   66    15.0     1.0     3       4        2      1      1.0   2.0      1
# 1733   65    11.0     4.0     3       2        4      3      1.0   2.0      5
# 1734   70    30.0     2.0     3       3        3      3      1.0   2.0      3
#
#       대중교통만족도
# 1730     3.25
# 1731     3.50
# 1732     4.00
# 1733     3.00
# 1734     3.75
#
# 17 data count:
# 332
#
# social research 2019
#     만나이  지역거주기간  향후거주의향  정주의식  거주지소속감  지역생활만족도  주거만족도  월평균가구소득  부채유무  삶의만족도  \
# 0    85    45.0     2.0     3       3        2      3      8.0   1.0      3
# 12   77    15.0     1.0     3       4        2      1      3.0   2.0      2
# 39   76    25.0     1.0     3       2        3      3      1.0   2.0      3
# ...

# %% [markdown]
# # 재개발 전 (17,19년도) / 재개발 후 (23년도) 데이터 합치기

# %%
def merge_preprocessed_data(data_dict, save_path=None):

    merged_data_list = []

    for year, data in data_dict.items():
        # 각 데이터에 년도 컬럼 추가
        data_copy = data.copy()
        data_copy['year'] = year
        merged_data_list.append(data_copy)

        print(f"{year}년 데이터 형태: {data_copy.shape}")
        print(f"{year}년 컬럼: {list(data_copy.columns)}")
        print("-" * 30)

    # 모든 데이터 합치기
    merged_data = pd.concat(merged_data_list, axis=0, ignore_index=True)

    print(f"\n=== 합친 결과 ===")
    print(f"전체 데이터 형태: {merged_data.shape}")
    print(f"년도별 데이터 수:")
    print(merged_data['year'].value_counts().sort_index())

    # 결측치 확인
    print(f"\n결측치 현황:")
    missing_info = merged_data.isnull().sum()
    if missing_info.sum() > 0:
        print(missing_info[missing_info > 0])
    else:
        print("결측치 없음")

    # CSV 저장
    if save_path:
        merged_data.to_csv(save_path, index=False, encoding='utf-8-sig')
        print(f"\n파일 저장 완료: {save_path}")

    return merged_data

# 1. 재개발 이전 데이터 (17, 18, 19) 합치기
redevelopment_before = {
    2017: new_social17,
    2019: new_social19
}

print("=== 재개발 이전 데이터 합치기 (2017, 2019) ===")
before_data = merge_preprocessed_data(
    redevelopment_before,
    save_path='redevelopment_before_2017_2019.csv'
)

print("\n" + "="*60 + "\n")

# 2. 재개발 이후 데이터 (23년만)
print("=== 재개발 이후 데이터 (2023) ===")
after_data = new_social23.copy()
after_data['year'] = 2023

print(f"2023년 데이터 형태: {after_data.shape}")
print(f"2023년 컬럼: {list(after_data.columns)}")

# 재개발 이후 데이터도 CSV로 저장
after_data.to_csv('redevelopment_after_2023.csv', index=False, encoding='utf-8-sig')
print("재개발 이후 파일 저장: redevelopment_after_2023.csv")

print("\n" + "="*60 + "\n")

# 3. 데이터 기본 통계 확인
def basic_statistics(data, data_name):
    """기본 통계 정보 출력"""
    print(f"=== {data_name} 기본 통계 ===")
    print(f"전체 행 수: {len(data)}")
    print(f"컬럼 수: {len(data.columns)}")

    # 년도별 분포
    if 'year' in data.columns:
        print("\n년도별 분포:")
        year_counts = data['year'].value_counts().sort_index()
        for year, count in year_counts.items():
            print(f"  {year}년: {count}개")

    # 목표 변수 기본 통계
    if '거주지만족도' in data.columns:
        print(f"\n거주지만족도 기본 통계:")
        print(data['거주지만족도'].describe())

    print("-" * 50)

# 기본 통계 확인
basic_statistics(before_data, "재개발 이전")
basic_statistics(after_data, "재개발 이후")

# 4. 컬럼 정보 최종 확인
print("=== 최종 컬럼 정보 ===")
print("재개발 이전 컬럼:", list(before_data.columns))
print("재개발 이후 컬럼:", list(after_data.columns))

# 컬럼이 모두 동일한지 확인
before_cols = set(before_data.columns)
after_cols = set(after_data.columns)

if before_cols == after_cols:
    print("\n✅ 재개발 이전/이후 컬럼이 모두 동일합니다!")
else:
    print(f"\n⚠️ 컬럼 차이 발견:")
    print(f"이전에만 있음: {before_cols - after_cols}")
    print(f"이후에만 있음: {after_cols - before_cols}")
# Out:
# === 재개발 이전 데이터 합치기 (2017, 2019) ===
# 2017년 데이터 형태: (332, 12)
# 2017년 컬럼: ['만나이', '지역거주기간', '향후거주의향', '정주의식', '거주지소속감', '지역생활만족도', '주거만족도', '월평균가구소득', '부채유무', '삶의만족도', '대중교통만족도', 'year']
# ------------------------------
# 2019년 데이터 형태: (376, 12)
# 2019년 컬럼: ['만나이', '지역거주기간', '향후거주의향', '정주의식', '거주지소속감', '지역생활만족도', '주거만족도', '월평균가구소득', '부채유무', '삶의만족도', '대중교통만족도', 'year']
# ------------------------------
#
# === 합친 결과 ===
# 전체 데이터 형태: (708, 12)
# 년도별 데이터 수:
# year
# 2017    332
# 2019    376
# Name: count, dtype: int64
#
# 결측치 현황:
# 결측치 없음
#
# 파일 저장 완료: redevelopment_before_2017_2019.csv
#
# ...
#
# === 재개발 이후 데이터 (2023) ===
# 2023년 데이터 형태: (461, 12)
# 2023년 컬럼: ['만나이', '지역거주기간', '향후거주의향', '정주의식', '거주지소속감', '지역생활만족도', '주거만족도', '월평균가구소득', '부채유무', '삶의만족도', '대중교통만족도', 'year']
# 재개발 이후 파일 저장: redevelopment_after_2023.csv
#
# ...
#
# === 재개발 이전 기본 통계 ===
# 전체 행 수: 708
# 컬럼 수: 12
#
# 년도별 분포:
#   2017년: 332개
#   2019년: 376개
# --------------------------------------------------
# === 재개발 이후 기본 통계 ===
# ...

# %%
# 원본 데이터의 교통 관련 컬럼 값 범위 확인
print("=== 2017년 원본 교통 컬럼 값 범위 ===")
transport_cols_17 = ['19-1.대중교통만족여부_지하철', '19-2.대중교통만족여부_기차', '19-3.대중교통만족여부_택시', '19-4.대중교통만족여부_버스']
for col in transport_cols_17:
    print(f"{col}: {social17[col].min()} ~ {social17[col].max()}")
    print(f"고유값: {sorted(social17[col].dropna().unique())}")

print("\n=== 2019년 원본 교통 컬럼 값 범위 ===")
transport_cols_19 = ['20-1.대중교통만족도_1지하철','20-2.대중교통만족도_2기차','20-3.대중교통만족도_3택시','20-4.대중교통만족도_4버스']
for col in transport_cols_19:
    print(f"{col}: {social19[col].min()} ~ {social19[col].max()}")
    print(f"고유값: {sorted(social19[col].dropna().unique())}")

print("\n=== 2023년 원본 교통 컬럼 값 범위 ===")
transport_cols_23 = ['지하철만족도코드1_1', '택시만족도코드1_1', '기차만족도코드1_1', '시내버스만족도코드1_1', '시외버스만족도코드1_1']
for col in transport_cols_23:
    print(f"{col}: {social23[col].min()} ~ {social23[col].max()}")
    print(f"고유값: {sorted(social23[col].dropna().unique())}")

# 매핑 후 확인
print("\n=== 매핑 후 대중교통만족도 값 범위 ===")
print(f"2017년 대중교통만족도: {new_social17['대중교통만족도'].min()} ~ {new_social17['대중교통만족도'].max()}")
print(f"2019년 대중교통만족도: {new_social19['대중교통만족도'].min()} ~ {new_social19['대중교통만족도'].max()}")
print(f"2023년 대중교통만족도: {new_social23['대중교통만족도'].min()} ~ {new_social23['대중교통만족도'].max()}")

# 5 이상인 값들 확인
print("\n=== 5 이상인 값들 확인 ===")
print(f"2017년 5 이상 개수: {(new_social17['대중교통만족도'] > 5).sum()}")
print(f"2019년 5 이상 개수: {(new_social19['대중교통만족도'] > 5).sum()}")
print(f"2023년 5 이상 개수: {(new_social23['대중교통만족도'] > 5).sum()}")
# Out:
# === 2017년 원본 교통 컬럼 값 범위 ===
# 19-1.대중교통만족여부_지하철: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 19-2.대중교통만족여부_기차: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 19-3.대중교통만족여부_택시: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 19-4.대중교통만족여부_버스: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
#
# === 2019년 원본 교통 컬럼 값 범위 ===
# 20-1.대중교통만족도_1지하철: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 20-2.대중교통만족도_2기차: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 20-3.대중교통만족도_3택시: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
# 20-4.대중교통만족도_4버스: 1 ~ 6
# 고유값: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6)]
#
# === 2023년 원본 교통 컬럼 값 범위 ===
# ...
